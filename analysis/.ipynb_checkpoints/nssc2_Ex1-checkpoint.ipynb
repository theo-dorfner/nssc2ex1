# %%
import numpy as np
import matplotlib.pyplot as plt
iterations = 30
resolutions = [125,250,1000,2000]
processes = [1,2,3,5,7,10,12,15,17,20,22,25,27,30,32,35,37,40]

# %% [markdown]
# # Collect Data

# %%
serialTime = [2.092500e+00 / 2000, 8.642756e+00 / 2000, 1.430785e+02 /2000, 1/2000] # this is for the four resolutions
print(serialTime)
# Out:
# [0.0010462499999999999, 0.004321378, 0.07153925, 0.0005]

# %%
# resolution 125
file125 = open("result125.txt",'r')
fullResults125 = []
run = []
for line in file125:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults125.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults125)
# Out:
# [[150.1593, 8.686535, 5165.51, 166.8241, 8.870327e-05], [150.1578, 8.686535, 5165.604, 166.8241, 5.02425e-05], [150.1483, 8.686535, 5166.242, 166.8241, 3.406807e-05], [150.093, 8.686535, 5169.936, 166.8241, 2.356964e-05], [149.9769, 8.68648, 5175.495, 166.8251, 1.963281e-05], [149.2293, 8.680215, 5185.216, 166.9161, 2.204175e-05], [147.6606, 8.660064, 5195.164, 167.2136, 1.955097e-05], [140.33, 8.542789, 5224.457, 170.0435, 1.6133e-05], [129.779, 8.223842, 5258.965, 177.4775, 1.625633e-05], [110.3106, 7.356255, 5319.353, 186.7396, 1.179121e-05], [79.71038, 5.843416, 5417.401, 196.5191, 1.46803e-05], [41.54207, 3.171823, 5556.846, 206.8644, 1.375024e-05], [41.52368, 3.171823, 5562.276, 206.8644, 1.345511e-05], [41.52336, 3.171823, 5562.371, 206.8644, 1.405204e-05], [10.34653, 0.9284134, 5749.712, 217.8198, 1.335414e-05], [10.33947, 0.9284134, 5752.465, 217.8198, 1.494856e-05], [10.3393, 0.9284134, 5752.532, 217.8198, 1.493133e-05], [10.33928, 0.9284134, 5752.538, 217.8198, 1.445083e-05]]

# %%
# resolution 250
file250 = open("result250.txt",'r')
fullResults250 = []
run = []
for line in file250:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults250.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults250)
# Out:
# [[210.3387, 8.677871, 11837.24, 208.1344, 0.0003681106], [210.3386, 8.677871, 11837.26, 208.1344, 0.0001800721], [210.3377, 8.677871, 11837.41, 208.1344, 0.0001224056], [210.3328, 8.677871, 11838.21, 208.1344, 8.051505e-05], [210.3256, 8.677871, 11839.4, 208.1344, 5.999183e-05], [210.3118, 8.677871, 11841.65, 208.1344, 4.402448e-05], [210.2999, 8.677871, 11843.23, 208.1344, 5.732526e-05], [210.2507, 8.677807, 11845.66, 208.1371, 4.819431e-05], [210.1593, 8.677432, 11847.47, 208.1492, 4.238234e-05], [209.9003, 8.675636, 11850.39, 208.1981, 2.812695e-05], [209.5427, 8.673286, 11853.06, 208.2605, 3.695832e-05], [206.1085, 8.653933, 11866.24, 209.1159, 3.347813e-05], [206.1047, 8.653933, 11867.14, 209.1159, 3.166945e-05], [199.7205, 8.587713, 11885.36, 213.0164, 3.047338e-05], [185.494, 8.296493, 11919.7, 218.4664, 2.845374e-05], [185.4934, 8.296493, 11919.9, 218.4664, 2.752939e-05], [158.3372, 7.453816, 11981.18, 224.0622, 2.620183e-05], [158.3368, 7.453816, 11981.33, 224.0622, 2.656861e-05]]

# %%
# resolution 1000
file1000 = open("result1000.txt",'r')
fullResults1000 = []
run = []
for line in file1000:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults1000.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults1000)
# Out:
# [[418.5323, 8.658001, 51896.97, 249.0387, 0.005601809], [418.5323, 8.658001, 51896.97, 249.0387, 0.002785194], [418.5323, 8.658001, 51896.98, 249.0387, 0.001965979], [418.5323, 8.658001, 51897.02, 249.0387, 0.001218735], [418.5322, 8.658001, 51897.09, 249.0387, 0.0008969842], [418.5321, 8.658001, 51897.21, 249.0387, 0.00104325], [418.5321, 8.658001, 51897.3, 249.0387, 0.0008732378], [418.532, 8.658001, 51897.44, 249.0387, 0.0007242528], [418.5319, 8.658001, 51897.53, 249.0387, 0.0006293063], [418.5318, 8.658001, 51897.68, 249.0387, 0.0003170679], [418.5317, 8.658001, 51897.77, 249.0387, 0.000535929], [418.5316, 8.658001, 51897.92, 249.0387, 0.0004731017], [418.5315, 8.658001, 51898.01, 249.0387, 0.0004419701], [418.5314, 8.658001, 51898.15, 249.0387, 0.0004037588], [418.5313, 8.658001, 51898.24, 249.0387, 0.0003957544], [418.5311, 8.658001, 51898.41, 249.0387, 0.0003469394], [418.5311, 8.658001, 51898.49, 249.0387, 0.0003313138], [418.5309, 8.658001, 51898.65, 249.0387, 0.000312689]]

# %%
# resolution 2000
file2000 = open("result2000.txt",'r')
fullResults2000 = []
run = []
for line in file2000:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults2000.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults2000)
# Out:
# [[591.7933, 8.656445, 105303.9, 257.6116, 0.02195151], [591.7933, 8.656445, 105303.9, 257.6116, 0.01130924], [591.7933, 8.656445, 105303.9, 257.6116, 0.007951972], [591.7933, 8.656445, 105303.9, 257.6116, 0.004813425], [591.7933, 8.656445, 105303.9, 257.6116, 0.004022581], [591.7933, 8.656445, 105304.0, 257.6116, 0.002468841], [591.7933, 8.656445, 105304.0, 257.6116, 0.002159651], [591.7933, 8.656445, 105304.0, 257.6116, 0.002744218], [591.7933, 8.656445, 105304.0, 257.6116, 0.002386554], [591.7933, 8.656445, 105304.1, 257.6116, 0.001468585], [591.7933, 8.656445, 105304.1, 257.6116, 0.002168091], [591.7933, 8.656445, 105304.1, 257.6116, 0.001887702], [591.7932, 8.656445, 105304.2, 257.6116, 0.001813543], [591.7932, 8.656445, 105304.2, 257.6116, 0.001683503], [591.7932, 8.656445, 105304.2, 257.6116, 0.001447985], [591.7932, 8.656445, 105304.3, 257.6116, 0.001470151], [591.7932, 8.656445, 105304.3, 257.6116, 0.001455094], [591.7932, 8.656445, 105304.3, 257.6116, 0.001374053]]

# %% [markdown]
# # Extract Time Values

# %%
times125 = []
times250 = []
times1000 = []
times2000 = []
for i in range(len(processes)):
    times125.append(fullResults125[i][-1])
    times250.append(fullResults250[i][-1])
    times1000.append(fullResults1000[i][-1])
    times2000.append(fullResults2000[i][-1])

# %%
timeOverview = [times125,times250,times1000,times2000]
parallelSpeedup = []
parallelEfficiency = []
for i,res in enumerate(timeOverview):
    runSpeed = []
    runEff = []
    for j,time in enumerate(res):
        sTime = serialTime[i]
        runSpeed.append(sTime/time)
        runEff.append(sTime/(time*processes[j]))
    parallelSpeedup.append(runSpeed)
    parallelEfficiency.append(runEff)

# %%
print(parallelEfficiency)
# Out:
# [[11.794942847090077, 10.412001791312136, 10.236858148994056, 8.87794637508252, 7.612984881648917, 4.7466739256184285, 4.459497406011057, 4.323436434637078, 3.785855580383691, 4.436567578730257, 3.2394990689439704, 3.0435832392743687, 2.879946726559649, 2.481846052245795, 2.448327821933872, 1.9997148315862625, 1.893804974307515, 1.810017140883949], [11.739346815875447, 11.9990215030535, 11.767920204086522, 10.734336003020553, 10.290396447078114, 9.815852452998877, 6.281957261656262, 5.97771534993792, 5.997750616939813, 7.681917164854347, 5.314805238097205, 5.163225066633052, 5.053799072514269, 4.7269431002840285, 4.74605666952745, 4.484950188040594, 4.457474916828328, 4.066243962329983], [12.770740666095541, 12.84277684067968, 12.129537836704595, 11.739918850283283, 11.393615246670851, 6.857344835849509, 6.8270111150326604, 6.58510858823512, 6.687031698984402, 11.281376954273831, 6.0675650896090545, 6.048530368840357, 5.99497986821247, 5.906104502655215, 5.648961988799114, 5.891457042436147, 5.835836730142973, 5.719680737090207], [0.022777476355840667, 0.022105817897577557, 0.020959161660361315, 0.020775227618587598, 0.01775690071339059, 0.020252418037451585, 0.019293240744299275, 0.012146751217772544, 0.012323946873141088, 0.01702318898803951, 0.010482619376803245, 0.010594892626060682, 0.010211237626303054, 0.009899992258206054, 0.010790857640099863, 0.009717174824704595, 0.009287038166272086, 0.009097174563135482]]

# %% [markdown]
# # Plotting

# %%
# parallel speedup
for i in range(4):
   plt.semilogy(processes,parallelSpeedup[i],'o-',label="Resolution = " + str(resolutions[i]))
#plt.plot(processes,parallelSpeedup[3],'o-',label="Resolution = " + str(resolutions[i]))
plt.legend()
plt.title("Parallel Speedup for MPI Parallelization")
plt.xlabel("Number of Processes")
plt.ylabel("Parallel Speedup")
#plt.savefig("parallelSpeedup.png",dpi=300)
# Out:
# Text(0, 0.5, 'Parallel Speedup')

# %%
# parallel speedup
for i in range(4):
    plt.semilogy(processes,parallelEfficiency[i],'o-',label="Resolution = " + str(resolutions[i]))
plt.legend()
plt.title("Parallel Efficiency for MPI Parallelization")
plt.xlabel("Number of Processes")
plt.ylabel("Parallel Efficiency")
#plt.savefig("parallelEfficiency.png",dpi=300)
# Out:
# Text(0, 0.5, 'Parallel Efficiency')
