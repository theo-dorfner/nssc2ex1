# %%
import numpy as np
import matplotlib.pyplot as plt
iterations = 30
resolutions = [125,250,1000,2000]
processes = [1,2,5,10,20,30,40]

# %% [markdown]
# # Collect Data

# %%
serialTime = [2.092500e+00 / 2000, 8.642756e+00 / 2000, 1.430785e+02 /2000, 1/2000] # this is for the four resolutions
print(serialTime)
# Out:
# [0.0010462499999999999, 0.004321378, 0.07153925, 0.0005]

# %%
# resolution 125
file125 = open("test_result.txt",'r')
fullResults125 = []
run = []
for line in file125:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults125.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults125)
# Out:
# [[150.1593, 8.686535, 5165.51, 166.8241, 2.668426e-10], [150.1578, 8.686535, 5165.604, 166.8241, 7.322366e-11], [150.093, 8.686535, 5169.936, 166.8241, 1.193071e-11], [149.2293, 8.680215, 5185.216, 166.9161, 3.254402e-12], [110.3106, 7.356255, 5319.353, 186.7396, 9.022739e-13], [41.52336, 3.171823, 5562.371, 206.8644, 5.317692e-13], [10.33928, 0.9284134, 5752.538, 217.8198, 3.183244e-13]]

# %%
# resolution 250
file250 = open("test_result.txt",'r')
fullResults250 = []
run = []
for line in file250:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults250.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults250)
# Out:
# [[150.1593, 8.686535, 5165.51, 166.8241, 2.668426e-10], [150.1578, 8.686535, 5165.604, 166.8241, 7.322366e-11], [150.093, 8.686535, 5169.936, 166.8241, 1.193071e-11], [149.2293, 8.680215, 5185.216, 166.9161, 3.254402e-12], [110.3106, 7.356255, 5319.353, 186.7396, 9.022739e-13], [41.52336, 3.171823, 5562.371, 206.8644, 5.317692e-13], [10.33928, 0.9284134, 5752.538, 217.8198, 3.183244e-13]]

# %%
# resolution 1000
file1000 = open("test_result.txt",'r')
fullResults1000 = []
run = []
for line in file1000:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults1000.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults1000)
# Out:
# [[150.1593, 8.686535, 5165.51, 166.8241, 2.668426e-10], [150.1578, 8.686535, 5165.604, 166.8241, 7.322366e-11], [150.093, 8.686535, 5169.936, 166.8241, 1.193071e-11], [149.2293, 8.680215, 5185.216, 166.9161, 3.254402e-12], [110.3106, 7.356255, 5319.353, 186.7396, 9.022739e-13], [41.52336, 3.171823, 5562.371, 206.8644, 5.317692e-13], [10.33928, 0.9284134, 5752.538, 217.8198, 3.183244e-13]]

# %%
# resolution 2000
file2000 = open("test_result.txt",'r')
fullResults2000 = []
run = []
for line in file2000:
    if("jacobiMPI" in line): 
        continue
    if("---" in line):
        fullResults2000.append(run)
        run = []
        continue
    num = float(line.split(" ")[1])
    run.append(num)
print(fullResults2000)
# Out:
# [[150.1593, 8.686535, 5165.51, 166.8241, 2.668426e-10], [150.1578, 8.686535, 5165.604, 166.8241, 7.322366e-11], [150.093, 8.686535, 5169.936, 166.8241, 1.193071e-11], [149.2293, 8.680215, 5185.216, 166.9161, 3.254402e-12], [110.3106, 7.356255, 5319.353, 186.7396, 9.022739e-13], [41.52336, 3.171823, 5562.371, 206.8644, 5.317692e-13], [10.33928, 0.9284134, 5752.538, 217.8198, 3.183244e-13]]

# %% [markdown]
# # Extract Time Values

# %%
times125 = []
times250 = []
times1000 = []
times2000 = []
for i in range(7):
    times125.append(fullResults125[i][-1])
    #times250.append(fullResults250[i][-1])
    #times1000.append(fullResults1000[i][-1])
    #times2000.append(fullResults2000[i][-1])

# %%
timeOverview = [times125,times250,times1000,times2000]
parallelSpeedup = []
parallelEfficiency = []
runSpeed = []
runEff = []
for i,res in enumerate(timeOverview):
    for j,time in enumerate(res):
        sTime = serialTime[i]
        runSpeed.append(sTime/time)
        runEff.append(sTime/(time*processes[j]))
    parallelSpeedup.append(runSpeed)
    parallelEfficiency.append(runEff)

# %%
print(parallelSpeedup)
# Out:
# [[3920850.7187383124, 14288414.427795604, 87693858.95726238, 321487634.2873437, 1159570281.2638156, 1967488903.0805092, 3286741449.917128], [3920850.7187383124, 14288414.427795604, 87693858.95726238, 321487634.2873437, 1159570281.2638156, 1967488903.0805092, 3286741449.917128], [3920850.7187383124, 14288414.427795604, 87693858.95726238, 321487634.2873437, 1159570281.2638156, 1967488903.0805092, 3286741449.917128], [3920850.7187383124, 14288414.427795604, 87693858.95726238, 321487634.2873437, 1159570281.2638156, 1967488903.0805092, 3286741449.917128]]

# %% [markdown]
# # Plotting

# %%
# parallel speedup
for i in range(4):
    plt.plot(processes,parallelSpeedup[i],'o-',label="Resolution = " + str(resolutions[i]))
plt.legend()
plt.title("Parallel Speedup for MPI Parallelization")
plt.xlabel("Number of Processes")
plt.ylabel("Parallel Speedup")
#plt.savefig("parallelSpeedup.png",dpi=300)
# Out:
# Text(0, 0.5, 'Parallel Speedup')

# %%
# parallel speedup
for i in range(4):
    plt.plot(processes,parallelEfficiency[i],'o-',label="Resolution = " + str(resolutions[i]))
plt.legend()
plt.title("Parallel Efficiency for MPI Parallelization")
plt.xlabel("Number of Processes")
plt.ylabel("Parallel Efficiency")
#plt.savefig("parallelEfficiency.png",dpi=300)
# Out:
# Text(0, 0.5, 'Parallel Efficiency')
